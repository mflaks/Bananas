# %% [markdown]
# # Navigation
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 2.0.10 which is incompatible.

# %% [markdown]
# The environment is already saved in the Workspace and can be accessed at the file path provided below.  Please run the next code cell without making any changes.

# %%
from unityagents import UnityEnvironment
import numpy as np

# please do not modify the line below
env = UnityEnvironment(file_name="/data/Banana_Linux_NoVis/Banana.x86_64")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [ 1.          0.          0.          0.          0.84408134  0.          0.
#   1.          0.          0.0748472   0.          1.          0.          0.
#   0.25755     1.          0.          0.          0.          0.74177343
#   0.          1.          0.          0.          0.25854847  0.          0.
#   1.          0.          0.09355672  0.          1.          0.          0.
#   0.31969345  0.          0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agent while it is training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
while True:
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 0.0

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agent while it is training.  However, **_after training the agent_**, you can download the saved model weights to watch the agent on your own machine!

# %%
# IMPORT LIBRARIES

import numpy as np
import torch
from torch import nn as nn
import torch.nn.functional as F
import torch.optim as optim
from collections import deque
import pickle

# %%
# CREATE A SUMTREE TO STORE THE EPISODES

class SumTree():

    def __init__(self, capacity):

        self.capacity = capacity                                    # number of leaf nodes (Priorities)
        self.tree = np.zeros(capacity*2 - 1)                        # array with total number of nodes
        self.data = np.zeros(capacity, dtype=object)                # array to store the data [S, A, S', R, done]
        self.height = np.log2(capacity) + 1                         # number of layer in the tree
        self.pointer = 0                                            # will be used to select where store new data

    def add(self, p, data):
        """
        Arguments:
        p -- scalar value: priority value = abs(expected - target)
        data -- list [S, A, R, S', done]

        Return:
        Add a new priority value to the leaf node, and associate this leaf node to a list containing [S, A, R, S', done]
        """
        # add a new priority and data to the tree.
        idx = self.capacity - 1 + self.pointer
        self.update(idx, p)
        self.data[self.pointer] = data
        self.pointer = self.pointer + 1
        # if the tree if full, we will replace existing priorities, starting from the beginning (First in First Out)
        if self.pointer > self.capacity-1:
            self.pointer = 0

    def _propagate(self, idx, change):
        """
        Arguments:
        idx -- scalar value
        change -- scalar value:  difference btw new and old priority

        Return:
        propagate the change from the leaf node to the root
        """

        # calculate the parent node of this index
        parent = (idx - 1) // 2
        # add the change to this parent node
        self.tree[parent] += change

        # if the parent node is not the root, repeat the process until the root node is updated
        if parent != 0:
            idx = parent
            self._propagate(idx, change)

    def total_priority(self):
        """
        sum of all priorities, value of the root node
        """
        return self.tree[0]

    def update(self, idx, p):
        """
        Arguments:
        idx -- scalar value: index of the leaf node that we want to update
        p -- scalar: new priority value

        Return:
        propagate the difference btw the new and old  priority value in each parent node until we reach the root node
        """
        # calculate the difference btw the new priority and old priority (change).
        change = p - self.tree[idx]
        self.tree[idx] = p
        # propagate this change from the leaf until the root node
        self._propagate(idx, change)

    def _retrieve(self, value, parent):
        """
        Arguments:
        value -- scalar:  number that represents the sum of the leaf nodes that we random choose to looking for.
        parent -- start with  0 (root node)

        Return:
        list with [index , priority, [S, A, R, Next S, done]]
        """

        left_node = parent*2 + 1
        right_node = left_node + 1

        if value < self.tree[left_node]:
            if left_node >= self.capacity-1:
                return [left_node, self.tree[left_node], self.data[left_node - self.capacity+1]]
            else:
                parent = left_node
                return self._retrieve(value, parent)

        else:
            if right_node >= self.capacity-1:
                return [right_node, self.tree[right_node], self.data[right_node - self.capacity+1]]
            else:
                parent = right_node
                value = value - self.tree[left_node]
                return self._retrieve(value, parent)

# %%
# CREATE PRIORITIZE EXPERIENCE REPLAY

# SUMTREE will be used to store the experiences

class PER():

    def __init__(self, capacity, epsilon_per, a_per, b_per, increment_b, absolute_error):

        self.capacity = capacity                            # maximum number of priorities (leaf nodes)
        self.epsilon_per = epsilon_per                      # add to the priority, avoid to have priority zero
        self.a_per = a_per                                  # [0,1]  0 uniform distribution
        self.b_per = b_per                                  # [0,1]  calculate Importance Sampling Weights  IS_Weights
        self.increment_b = increment_b                      # how fast move b_per to 1.
        self.absolute_error = absolute_error                # maximum Priority value
        # Create a SumTree
        self.sumtree = SumTree(self.capacity)

    def add(self, data):
        """
        Arguments:
        data -- list [S, A, R, S', done]  each element of the list can be anything that you want

        Return
        it will include the data in the Sum Tree and add a new priority value to the leaf node
        """
        # calculate the priority of a new experiences. The Error was not calculated yet
        p_max = max(self.sumtree.tree[self.capacity-1:])
        if p_max == 0:
            p = self.absolute_error
        else:
            p = p_max
        self.sumtree.add(p, data)

    def sample(self, n):
        """
        Arguments:
        n -- number of elements you want to retrieve from the Sum Tree

        Return:
        idxs -- list with "n"" indexes related to the samples [index1, index2, etc...] - scalar
        mini_batches -- list with "n" experiences [[S1, A1, R1, S1', done1], [S1, A1, R1, S1', done1], etc...] - tensors
        IS_Weights -- list with "n" IS_weights  [IS_Weight_1, IS_Weight_2, etc.. ]  - scalar
        """

        # create a list to store the values
        idxs = []
        mini_batches = []
        IS_Weights = []

        # divide the priorities in "n" ranges. Select one experience on each range using an uniform distribution
        total_priority = self.sumtree.total_priority()
        priority_segment = total_priority/n

        # calculate Max Weight
        # the priorities added on the tree, are already (error + epsilon)^ per_a

        # if there are empty leaf nodes, some priorities are equal to 0
        if min(self.sumtree.tree[self.capacity - 1:]) == 0:
            # we only want to look for the min priority among the leaf nodes that has an experience
            start = self.capacity - 1
            end = start + self.sumtree.pointer
            p_min = min(self.sumtree.tree[start: end] / total_priority)
        # if the tree is full
        else:
            p_min = min(self.sumtree.tree[self.capacity - 1:] / total_priority)

        max_weight = (1 / (p_min * n)) ** self.b_per


        for i in range(n):

            # random select a number in each range of priorities
            min_value, max_value = i*priority_segment, (i+1)*priority_segment
            value = np.random.uniform(min_value, max_value)
            # get priority and [S,A,R,S', done] from the SumTree
            idx, priority, mini_batch = self.sumtree._retrieve(value, parent=0)

            # calculate IS Weight
            probability = priority / total_priority
            # normalize the IS Weight
            IS_Weight = ((1 / (probability*n))**self.b_per) / max_weight

            # store the index, mini_batch, IS Weight
            idxs.append(idx)
            mini_batches.append(mini_batch)
            IS_Weights.append(IS_Weight)

        # update per_b each time we sample experiences to train the Network
        self.b_per = min(self.b_per + self.increment_b, 1)


        return idxs, mini_batches, IS_Weights


    def update(self, idx, error):
        """
        Arguments:
        idx --list of Indexes [idx_1, idx_2, ... idx_n]
        error -- list of scalar values [priority_1, priority_2,.., priority_n]

        Return:
        It will include the error on the SumTree and recalculate its values from the leaf to the root
        """
        error = np.array(error)
        priority = error + self.epsilon_per
        priority = priority ** self.a_per
        priorities = np.minimum(priority, self.absolute_error)
        for i, j in list(zip(idx, priorities)):
            self.sumtree.update(i, j)

# %%
# CREATE A DUELING DQN

class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(in_features=37, out_features=64)
        self.fc2 = nn.Linear(in_features=64, out_features=64)
        self.fc3 = nn.Linear(in_features=64, out_features=64)
        self.fc4 = nn.Linear(in_features=64, out_features=64)
        self.fc5 = nn.Linear(in_features=64, out_features=1)
        self.fc6 = nn.Linear(in_features=64, out_features=4)

    def forward(self, t):
        t = self.fc1(t)
        t = F.relu(t)

        t = self.fc2(t)
        t = F.relu(t)

        t = self.fc3(t)
        t = F.relu(t)
        
        t = self.fc4(t)
        t = F.relu(t)
        
        # Value of the State
        v = self.fc5(t)

        # Advantage of take an Action
        a = self.fc6(t)
        average_a = a.mean(dim=1).unsqueeze(1)

        # Q value =  V + A - Average_A
        q = torch.add(v, torch.add(a, - average_a))

        return q

# %%
# CREATE AN AGENT TO INTERACT WITH THE ENVIRONMENT

class Agent():
    """ Create an Agent that will interact with the environment and decide the best action to take in order to receive
    more rewards. """

    def __init__(self, env, state_size, action_size, epsilon, epsilon_decay, epsilon_min, gamma, tau, batch_size,
                 update_every, learning_rate, capacity, epsilon_per, a_per, b_per, increment_b, absolute_error,
                 terminal_state):

        # Environment
        self.env = env                                    # instance of an environment 
        self.state_size = state_size                      # state size -- input of the DQN (number of features)
        self.action_size = action_size                    # number of action -- output DQN

        # Exploration Rate
        self.epsilon = epsilon                            # exploration rate
        self.epsilon_decay = epsilon_decay                # factor to decrease the exploration rate at each episode
        self.epsilon_min = epsilon_min                    # min exploration rate

        # Train DQN
        self.gamma = gamma                                # discount rate of the future rewards
        self.tau = tau                                    # learning rate to update the parameters of the DQN_Target
        self.batch_size = batch_size                      # number of examples the DQN will train at the same time
        self.update_every = update_every                  # number of time steps we need to take, before update DQN and DQN_Target
        self.learning_rate = learning_rate                # learning rate to train the DQN
        self.counter = 0                                  # count number of steps in order to update the DQN and DQN_Target
        self.terminal_state = terminal_state              # Q Value of the Terminal State

        # Prioritize Experience Replay - PER
        self.capacity = capacity                          # maximum number of experiences (leaf nodes)
        self.epsilon_per = epsilon_per                    # add to the priority, avoid priority equal zero
        self.a_per = a_per                                # [0,1]  0 uniform distribution
        self.b_per = b_per                                # [0,1]  calculate Importance Sampling Weights  IS_Weights
        self.increment_b = increment_b                    # how fast move b_per to 1.
        self.absolute_error = absolute_error              # maximum Priority value

        # Create a Prioritize Experience Replay - PER
        # Store Experiences (S, A, R, S', P)
        self.per = PER(self.capacity, self.epsilon_per, self.a_per, self.b_per, self.increment_b, self.absolute_error)


    def create_Dueling_DQN(self):
        # Create a Dueling  DQN

        # Create a DQN to calculate the Q(state,action)
        self.DQN = Network()

        # Create a DQN Target to calculate the Q(next_state, action)
        self.DQN_Target = Network()

        # set DQN_Target parameters equal to DQN
        self.DQN_Target.load_state_dict(self.DQN.state_dict())


    def update_DQN_Target(self):
        # Soft update the parameters of the DQN_Target:
        # p_target = (1-tau)*p_target + tau*p_dqn

        
        for p_dqn, p_target in zip(self.DQN.parameters(), self.DQN_Target.parameters()):
            p_target.data.copy_((1-self.tau)*p_target.data + self.tau*p_dqn.data)

        
    def train_DQN(self, idxs, mini_batches, IS_Weights):
        """
        Arguments:
        idx -- list with index of the samples (lef nodes of the SumTree)
        mini_batches -- List os Tensors [State, Action, Reward, Next State, done]
        IS_Weights -- list with [IS_Weights]

        Return:
        loss -- value of the lost function
        error -- list of tensors with the priority value to update the SumTree
        idx -- list with index of the samples (lef nodes of the SumTree)
        """

        # CALCULATE THE LOSS

        # retrieve experience  [S, A, R, S', done]  from mini_batches
        # Concatenate the values
        states, actions, rewards, next_states, dones = list(zip(*mini_batches))
        states = torch.cat(states, 0)
        next_states = torch.cat(next_states, 0)
        actions = torch.cat(actions, 0)
        rewards = torch.cat(rewards, 0)
        dones = torch.cat(dones, 0)


        # Importance Sampling Weight - Prioritize Experience Replay-PER:   shape (batch_size, 1)
        IS_Weights = torch.tensor(IS_Weights, dtype=torch.float32).unsqueeze(1)


        # Find the expected Q(state, action).  shape (batch_size, 1)
        expected = self.DQN(states).gather(1, actions)


        # DOUBLE DQN / FIXED TARGET  
        
        # Using DQN -- Find the  best action using as input Next_State: Q(Next_State, all actions)
        _, action_DQN = self.DQN(next_states).max(1)
        action_DQN = action_DQN.unsqueeze(1)

        # Using DQN_Target -- Find the Q Value:    Q(Next_State, best action found using Next State on DQN)
        Q_Next = self.DQN_Target(next_states).detach().gather(1, action_DQN)


        # Q(next) = 0,  if it is a terminal state and the game is over
        if self.terminal_state == 0:
            target = (rewards + (self.gamma * Q_Next * (1 - dones))).detach()
        else:
            target = (rewards + (self.gamma * Q_Next)).detach()


        # calculate the error - absolute value ==> convert to a list with scalar values
        error1 = torch.abs(expected - target).detach()
        error = [i.item() for i in error1.view(-1, 1)]
            
        # calculate the Loss using the Importance Sampling Weights  -  PER
        loss = torch.sum(IS_Weights * (expected - target) ** 2)

        # define the optimizer ADAM or SGD
        self.optimizer = optim.SGD(self.DQN.parameters(), lr=self.learning_rate)

        # zero gradients.  This tensor accumulates the gradients at each step.
        self.optimizer.zero_grad()

        # Calculate the gradients.
        loss.backward()

        # update parameters
        self.optimizer.step()


        return idxs, error, loss.item()


    def acc(self, state):

        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)

        # Exploration x Exploitation
        if np.random.rand() < self.epsilon:
            action = np.random.randint(self.action_size)
            return action

        # Greedy Policy, take the best action with the highest Q value
        else:
            action = self.DQN(state).argmax(dim=1).item()
            return action


    def update_epsilon(self):

        # after each episode the exploration rate should decrease and the agent will exploit more the best actions
        self.epsilon = max(self.epsilon_min, self.epsilon_decay*self.epsilon)


    def step(self, state, action, reward, next_state, done):
        """
        Arguments:
        state -- tensor  torch.Size([1, number of features])
        action -- tensor torch.Size([1, 1])
        reward -- tensor torch.Size([1, 1])
        next_state -- tensor  torch.Size([1, number of features])
        done --  tensor  torch.Size([1, 1])    False=0, True=1
        """

        # Convert to Tensor (1, number of features)
        state = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = torch.tensor(action).unsqueeze(0).unsqueeze(0)
        reward = torch.tensor(reward, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        next_state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0)
        done = torch.tensor(done, dtype=torch.float32).unsqueeze(0).unsqueeze(0)

        # add new experiences to PER
        self.per.add([state, action, reward, next_state, done])


        # Count the number of experiences added on the SumTree
        self.counter = self.counter + 1


        # Check if we have more experiences than the mini_batch size
        if self.counter >= self.batch_size:

            # Only train the DQN after we add "x" number of new experiences
            if self.counter % self.update_every == 0:


                # retrieve samples from PER
                # list with Index [scalar], mini_batches[tensors] and IS_Weights [scalar]
                idxs, mini_batches, IS_Weights = self.per.sample(self.batch_size)


                # Train DQN and calculate the Loss
                idxs, error, loss = self.train_DQN(idxs, mini_batches, IS_Weights)

                # update the priority value: PER
                self.per.update(idxs, error)


                # update DQN_Target Parameters - Soft Update
                self.update_DQN_Target()

# %%
def DQN_Model(env, num_episodes):

    # save the last 100 scores
    scores = deque(maxlen=100)
    all_scores=[]
    
    # Create an Agent
    agent = Agent(env, state_size=37, action_size=4, epsilon=1, epsilon_decay=0.9985, epsilon_min=0.01, gamma=0.97, tau=0.01,
                  batch_size=64, update_every=4, learning_rate=0.01, capacity=2**14, epsilon_per=0.0001, a_per=1, b_per=0.5,
                  increment_b=0.0000025, absolute_error=1, terminal_state=None)

    
    # Create Networks: DQN and DQN_Target
    agent.create_Dueling_DQN()


    # loop over the episodes
    for i in range(1, num_episodes + 1):
        score = 0
        r = []
        
        # reset the environment
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations[0]

        while True:
            # Choose an action
            action = agent.acc(state)

            # Take an action on the environment
            env_info = env.step(action)[brain_name]
            reward = env_info.rewards[0]
            next_state = env_info.vector_observations[0]
            done = env_info.local_done[0]

            # Train the model
            agent.step(state, action, reward, next_state, done)

            # actual state will be the next_state of previous step
            state = next_state

            # calculate the total score in 1 episode
            score = score + reward
            r.append(reward)
            if done:
                break

        # save the score of each episode on the list
        scores.append(score)

        if i >= 0:
            all_scores.append(np.average(scores))
            print('Episode:{}......Average Score:{:.2f}......Epsilon:{:.2f}....b_per:{:.2f}.....experience:{:.2f}'.format(i, np.average(scores), agent.epsilon, agent.per.b_per, agent.counter))
            print('blue bananas', r.count(-1), 'nothing', r.count(0), 'yellow bananas', r.count(1))
            print()
            if np.average(scores) >= 13:
                print('Congratulations, problem solved!!!')
                break
        
        # After each episode, update the exploration rate
        agent.update_epsilon()
    
    # Save Parameters
    print('saving parameters...')
    torch.save(agent.DQN.state_dict(), 'parameters3.pt')
    
    # Save All Scores - Average of 100 episodes
    print('saving scores...')
    file_out = open('all_scores3.pickle', 'wb')
    pickle.dump(all_scores, file_out)
    file_out.close()

    return all_scores

# %%
all_scores = DQN_Model(env, num_episodes=2500)
# Out:
# Episode:1......Average Score:0.00......Epsilon:1.00....b_per:0.50.....experience:300.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:2......Average Score:0.00......Epsilon:1.00....b_per:0.50.....experience:600.00
# blue bananas 0 nothing 300 yellow bananas 0
#
# Episode:3......Average Score:-0.67......Epsilon:1.00....b_per:0.50.....experience:900.00
# blue bananas 2 nothing 298 yellow bananas 0
#
# Episode:4......Average Score:-0.25......Epsilon:1.00....b_per:0.50.....experience:1200.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:5......Average Score:-0.20......Epsilon:0.99....b_per:0.50.....experience:1500.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:6......Average Score:-0.17......Epsilon:0.99....b_per:0.50.....experience:1800.00
# blue bananas 0 nothing 300 yellow bananas 0
#
# Episode:7......Average Score:-0.43......Epsilon:0.99....b_per:0.50.....experience:2100.00
# blue bananas 3 nothing 296 yellow bananas 1
#
# Episode:8......Average Score:-0.50......Epsilon:0.99....b_per:0.50.....experience:2400.00
# blue bananas 1 nothing 299 yellow bananas 0
#
# Episode:9......Average Score:-0.44......Epsilon:0.99....b_per:0.50.....experience:2700.00
# blue bananas 0 nothing 300 yellow bananas 0
#
00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:252......Average Score:0.78......Epsilon:0.69....b_per:0.55.....experience:75600.00
# blue bananas 2 nothing 295 yellow bananas 3
#
# Episode:253......Average Score:0.80......Epsilon:0.69....b_per:0.55.....experience:75900.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:254......Average Score:0.81......Epsilon:0.68....b_per:0.55.....experience:76200.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:255......Average Score:0.82......Epsilon:0.68....b_per:0.55.....experience:76500.00
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:256......Average Score:0.83......Epsilon:0.68....b_per:0.55.....experience:76800.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:257......Average Score:0.85......Epsilon:0.68....b_per:0.55.....experience:77100.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:258......Average Score:0.88......Epsilon:0.68....b_per:0.55.....experience:77400.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:259......Average Score:0.88......Epsilon:0.68....b_per:0.55.....experience:77700.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:260......Average Score:0.87......Epsilon:0.68....b_per:0.55.....experience:78000.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:261......Average Score:0.88......Epsilon:0.68....b_per:0.55.....experience:78300.00
# blue bananas 1 nothing 295 yellow bananas 4
#
# Episode:262......Average Score:0.87......Epsilon:0.68....b_per:0.55.....experience:78600.00
# blue bananas 1 nothing 299 yellow bananas 0
#
# Episode:263......Average Score:0.88......Epsilon:0.67....b_per:0.55.....experience:78900.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:264......Average Score:0.88......Epsilon:0.67....b_per:0.55.....experience:79200.00
# blue bananas 2 nothing 296 yellow bananas 2
#
# Episode:265......Average Score:0.88......Epsilon:0.67....b_per:0.55.....experience:79500.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:266......Average Score:0.94......Epsilon:0.67....b_per:0.55.....experience:79800.00
# blue bananas 0 nothing 295 yellow bananas 5
#
# Episode:267......Average Score:0.96......Epsilon:0.67....b_per:0.55.....experience:80100.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:268......Average Score:0.95......Epsilon:0.67....b_per:0.55.....experience:80400.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:269......Average Score:0.94......Epsilon:0.67....b_per:0.55.....experience:80700.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:270......Average Score:0.93......Epsilon:0.67....b_per:0.55.....experience:81000.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:271......Average Score:0.95......Epsilon:0.67....b_per:0.55.....experience:81300.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:272......Average Score:1.01......Epsilon:0.67....b_per:0.55.....experience:81600.00
# blue bananas 0 nothing 293 yellow bananas 7
#
# Episode:273......Average Score:0.98......Epsilon:0.66....b_per:0.55.....experience:81900.00
# blue bananas 0 nothing 300 yellow bananas 0
#
# Episode:274......Average Score:1.00......Epsilon:0.66....b_per:0.55.....experience:82200.00
# blue bananas 0 nothing 300 yellow bananas 0
#
# Episode:275......Average Score:1.03......Epsilon:0.66....b_per:0.55.....experience:82500.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:276......Average Score:1.04......Epsilon:0.66....b_per:0.55.....experience:82800.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:277......Average Score:1.05......Epsilon:0.66....b_per:0.55.....experience:83100.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:278......Average Score:1.07......Epsilon:0.66....b_per:0.55.....experience:83400.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:279......Average Score:1.07......Epsilon:0.66....b_per:0.55.....experience:83700.00
# blue bananas 1 nothing 297 yellow bananas 2
#
# Episode:280......Average Score:1.10......Epsilon:0.66....b_per:0.55.....experience:84000.00
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:281......Average Score:1.12......Epsilon:0.66....b_per:0.55.....experience:84300.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:282......Average Score:1.13......Epsilon:0.66....b_per:0.55.....experience:84600.00
# blue bananas 2 nothing 297 yellow bananas 1
#
# Episode:283......Average Score:1.19......Epsilon:0.65....b_per:0.55.....experience:84900.00
# blue bananas 1 nothing 295 yellow bananas 4
#
# Episode:284......Average Score:1.20......Epsilon:0.65....b_per:0.55.....experience:85200.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:285......Average Score:1.22......Epsilon:0.65....b_per:0.55.....experience:85500.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:286......Average Score:1.22......Epsilon:0.65....b_per:0.55.....experience:85800.00
# blue bananas 3 nothing 293 yellow bananas 4
#
# Episode:287......Average Score:1.24......Epsilon:0.65....b_per:0.55.....experience:86100.00
# blue bananas 0 nothing 300 yellow bananas 0
#
# Episode:288......Average Score:1.25......Epsilon:0.65....b_per:0.55.....experience:86400.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:289......Average Score:1.27......Epsilon:0.65....b_per:0.55.....experience:86700.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:290......Average Score:1.24......Epsilon:0.65....b_per:0.55.....experience:87000.00
# blue bananas 3 nothing 294 yellow bananas 3
#
# Episode:291......Average Score:1.23......Epsilon:0.65....b_per:0.55.....experience:87300.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:292......Average Score:1.28......Epsilon:0.65....b_per:0.55.....experience:87600.00
# blue bananas 2 nothing 294 yellow bananas 4
#
# Episode:293......Average Score:1.34......Epsilon:0.65....b_per:0.55.....experience:87900.00
# blue bananas 0 nothing 294 yellow bananas 6
#
# Episode:294......Average Score:1.37......Epsilon:0.64....b_per:0.56.....experience:88200.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:295......Average Score:1.42......Epsilon:0.64....b_per:0.56.....experience:88500.00
# blue bananas 0 nothing 295 yellow bananas 5
#
# Episode:296......Average Score:1.45......Epsilon:0.64....b_per:0.56.....experience:88800.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:297......Average Score:1.49......Epsilon:0.64....b_per:0.56.....experience:89100.00
# blue bananas 1 nothing 294 yellow bananas 5
#
# Episode:298......Average Score:1.47......Epsilon:0.64....b_per:0.56.....experience:89400.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:322......Average Score:1.66......Epsilon:0.62....b_per:0.56.....experience:96600.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:323......Average Score:1.68......Epsilon:0.62....b_per:0.56.....experience:96900.00
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:324......Average Score:1.68......Epsilon:0.62....b_per:0.56.....experience:97200.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:325......Average Score:1.69......Epsilon:0.61....b_per:0.56.....experience:97500.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:326......Average Score:1.71......Epsilon:0.61....b_per:0.56.....experience:97800.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:327......Average Score:1.71......Epsilon:0.61....b_per:0.56.....experience:98100.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:328......Average Score:1.73......Epsilon:0.61....b_per:0.56.....experience:98400.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:329......Average Score:1.76......Epsilon:0.61....b_per:0.56.....experience:98700.00
# blue bananas 0 nothing 296 yellow bananas 4
#
# Episode:330......Average Score:1.79......Epsilon:0.61....b_per:0.56.....experience:99000.00
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:331......Average Score:1.83......Epsilon:0.61....b_per:0.56.....experience:99300.00
# blue bananas 3 nothing 292 yellow bananas 5
#
# Episode:332......Average Score:1.85......Epsilon:0.61....b_per:0.56.....experience:99600.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:333......Average Score:1.87......Epsilon:0.61....b_per:0.56.....experience:99900.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:334......Average Score:1.89......Epsilon:0.61....b_per:0.56.....experience:100200.00
# blue bananas 1 nothing 297 yellow bananas 2
#
# Episode:335......Average Score:1.94......Epsilon:0.61....b_per:0.56.....experience:100500.00
# blue bananas 1 nothing 294 yellow bananas 5
#
# Episode:336......Average Score:1.95......Epsilon:0.60....b_per:0.56.....experience:100800.00
# blue bananas 0 nothing 298 yellow bananas 2
#
# Episode:337......Average Score:1.97......Epsilon:0.60....b_per:0.56.....experience:101100.00
# blue bananas 0 nothing 297 yellow bananas 3
#
# Episode:338......Average Score:1.97......Epsilon:0.60....b_per:0.56.....experience:101400.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:339......Average Score:1.97......Epsilon:0.60....b_per:0.56.....experience:101700.00
# blue bananas 0 nothing 299 yellow bananas 1
#
# Episode:340......Average Score:1.96......Epsilon:0.60....b_per:0.56.....experience:102000.00
# blue bananas 2 nothing 295 yellow bananas 3
#
# Episode:341......Average Score:1.92......Epsilon:0.60....b_per:0.56.....experience:102300.00
# blue bananas 3 nothing 295 yellow bananas 2
#
# Episode:342......Average Score:1.93......Epsilon:0.60....b_per:0.56.....experience:102600.00
# blue bananas 1 nothing 295 yellow bananas 4
#
# Episode:343......Average Score:1.95......Epsilon:0.60....b_per:0.56.....experience:102900.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:344......Average Score:1.92......Epsilon:0.60....b_per:0.56.....experience:103200.00
# blue bananas 2 nothing 296 yellow bananas 2
#
# Episode:345......Average Score:1.91......Epsilon:0.60....b_per:0.56.....experience:103500.00
# blue bananas 1 nothing 293 yellow bananas 6
#
# Episode:346......Average Score:1.93......Epsilon:0.60....b_per:0.56.....experience:103800.00
# blue bananas 1 nothing 296 yellow bananas 3
#
# Episode:347......Average Score:1.96......Epsilon:0.59....b_per:0.57.....experience:104100.00
# blue bananas 0 nothing 297 yellow bananas 2
#
# Episode:348......Average Score:1.96......Epsilon:0.59....b_per:0.57.....experience:104400.00
# blue bananas 1 nothing 299 yellow bananas 0
#
# Episode:349......Average Score:1.95......Epsilon:0.59....b_per:0.57.....experience:104700.00
# blue bananas 4 nothing 293 yellow bananas 3
#
# Episode:350......Average Score:1.94......Epsilon:0.59....b_per:0.57.....experience:105000.00
# blue bananas 1 nothing 298 yellow bananas 1
#
# Episode:351......Average Score:1.99......Epsilon:0.59....b_per:0.57.....experience:105300.00
# ...
#
# Episode:1288......Average Score:11.78......Epsilon:0.14....b_per:0.74.....experience:386400.00
# blue bananas 0 nothing 283 yellow bananas 17
#
# Episode:1289......Average Score:11.77......Epsilon:0.14....b_per:0.74.....experience:386700.00
# blue bananas 2 nothing 284 yellow bananas 14
#
# Episode:1290......Average Score:11.75......Epsilon:0.14....b_per:0.74.....experience:387000.00
# blue bananas 0 nothing 291 yellow bananas 9
#
# Episode:1291......Average Score:11.77......Epsilon:0.14....b_per:0.74.....experience:387300.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1292......Average Score:11.72......Epsilon:0.14....b_per:0.74.....experience:387600.00
# blue bananas 2 nothing 284 yellow bananas 14
#
# Episode:1293......Average Score:11.68......Epsilon:0.14....b_per:0.74.....experience:387900.00
# blue bananas 1 nothing 290 yellow bananas 9
#
# Episode:1294......Average Score:11.67......Epsilon:0.14....b_per:0.74.....experience:388200.00
# blue bananas 2 nothing 287 yellow bananas 11
#
# Episode:1295......Average Score:11.66......Epsilon:0.14....b_per:0.74.....experience:388500.00
# blue bananas 0 nothing 291 yellow bananas 9
#
# Episode:1296......Average Score:11.66......Epsilon:0.14....b_per:0.74.....experience:388800.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1297......Average Score:11.70......Epsilon:0.14....b_per:0.74.....experience:389100.00
# blue bananas 2 nothing 283 yellow bananas 15
#
# Episode:1298......Average Score:11.75......Epsilon:0.14....b_per:0.74.....experience:389400.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1299......Average Score:11.74......Epsilon:0.14....b_per:0.74.....experience:389700.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1300......Average Score:11.80......Epsilon:0.14....b_per:0.74.....experience:390000.00
# blue bananas 0 nothing 287 yellow bananas 13
#
# Episode:1301......Average Score:11.87......Epsilon:0.14....b_per:0.74.....experience:390300.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1302......Average Score:11.89......Epsilon:0.14....b_per:0.74.....experience:390600.00
# blue bananas 4 nothing 280 yellow bananas 16
#
# Episode:1303......Average Score:11.90......Epsilon:0.14....b_per:0.74.....experience:390900.00
# blue bananas 1 nothing 286 yellow bananas 13
#
# Episode:1304......Average Score:11.86......Epsilon:0.14....b_per:0.74.....experience:391200.00
# blue bananas 1 nothing 293 yellow bananas 6
#
# Episode:1305......Average Score:11.94......Epsilon:0.14....b_per:0.74.....experience:391500.00
# blue bananas 1 nothing 282 yellow bananas 17
#
# Episode:1306......Average Score:12.03......Epsilon:0.14....b_per:0.74.....experience:391800.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1307......Average Score:12.01......Epsilon:0.14....b_per:0.75.....experience:392100.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1308......Average Score:12.03......Epsilon:0.14....b_per:0.75.....experience:392400.00
# blue bananas 0 nothing 287 yellow bananas 13
#
# Episode:1309......Average Score:12.06......Epsilon:0.14....b_per:0.75.....experience:392700.00
# blue bananas 0 nothing 283 yellow bananas 17
#
# Episode:1310......Average Score:12.04......Epsilon:0.14....b_per:0.75.....experience:393000.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1311......Average Score:12.06......Epsilon:0.14....b_per:0.75.....experience:393300.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1312......Average Score:12.10......Epsilon:0.14....b_per:0.75.....experience:393600.00
# blue bananas 1 nothing 284 yellow bananas 15
#
# Episode:1313......Average Score:12.10......Epsilon:0.14....b_per:0.75.....experience:393900.00
# blue bananas 1 nothing 289 yellow bananas 10
#
# Episode:1314......Average Score:12.04......Epsilon:0.14....b_per:0.75.....experience:394200.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1315......Average Score:12.07......Epsilon:0.14....b_per:0.75.....experience:394500.00
# blue bananas 1 nothing 281 yellow bananas 17
#
# Episode:1316......Average Score:12.12......Epsilon:0.14....b_per:0.75.....experience:394800.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1317......Average Score:12.08......Epsilon:0.14....b_per:0.75.....experience:395100.00
# blue bananas 1 nothing 290 yellow bananas 9
#
# Episode:1318......Average Score:12.08......Epsilon:0.14....b_per:0.75.....experience:395400.00
# blue bananas 0 nothing 287 yellow bananas 13
#
# Episode:1319......Average Score:12.15......Epsilon:0.14....b_per:0.75.....experience:395700.00
# blue bananas 0 nothing 282 yellow bananas 18
#
# Episode:1320......Average Score:12.19......Epsilon:0.14....b_per:0.75.....experience:396000.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1321......Average Score:12.14......Epsilon:0.14....b_per:0.75.....experience:396300.00
# blue bananas 2 nothing 289 yellow bananas 9
#
# Episode:1322......Average Score:12.14......Epsilon:0.14....b_per:0.75.....experience:396600.00
# blue bananas 2 nothing 286 yellow bananas 12
#
# Episode:1323......Average Score:12.14......Epsilon:0.14....b_per:0.75.....experience:396900.00
# blue bananas 1 nothing 282 yellow bananas 17
#
# Episode:1324......Average Score:12.15......Epsilon:0.14....b_per:0.75.....experience:397200.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1325......Average Score:12.13......Epsilon:0.14....b_per:0.75.....experience:397500.00
# blue bananas 1 nothing 288 yellow bananas 11
#
# Episode:1326......Average Score:12.08......Epsilon:0.14....b_per:0.75.....experience:397800.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1327......Average Score:12.14......Epsilon:0.14....b_per:0.75.....experience:398100.00
# blue bananas 0 nothing 281 yellow bananas 19
#
# Episode:1328......Average Score:12.18......Epsilon:0.14....b_per:0.75.....experience:398400.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1329......Average Score:12.23......Epsilon:0.14....b_per:0.75.....experience:398700.00
# blue bananas 2 nothing 280 yellow bananas 18
#
# Episode:1330......Average Score:12.28......Epsilon:0.14....b_per:0.75.....experience:399000.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1331......Average Score:12.33......Epsilon:0.14....b_per:0.75.....experience:399300.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1332......Average Score:12.39......Epsilon:0.14....b_per:0.75.....experience:399600.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1333......Average Score:12.33......Epsilon:0.14....b_per:0.75.....experience:399900.00
# blue bananas 1 nothing 288 yellow bananas 11
#
# Episode:1334......Average Score:12.42......Epsilon:0.14....b_per:0.75.....experience:400200.00
# blue bananas 0 nothing 281 yellow bananas 19
#
# Episode:1335......Average Score:12.40......Epsilon:0.13....b_per:0.75.....experience:400500.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1336......Average Score:12.37......Epsilon:0.13....b_per:0.75.....experience:400800.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1337......Average Score:12.34......Epsilon:0.13....b_per:0.75.....experience:401100.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1338......Average Score:12.35......Epsilon:0.13....b_per:0.75.....experience:401400.00
# blue bananas 0 nothing 290 yellow bananas 10
#
# Episode:1339......Average Score:12.36......Epsilon:0.13....b_per:0.75.....experience:401700.00
# blue bananas 2 nothing 286 yellow bananas 12
#
# Episode:1340......Average Score:12.35......Epsilon:0.13....b_per:0.75.....experience:402000.00
# blue bananas 0 nothing 289 yellow bananas 11
#
# Episode:1341......Average Score:12.32......Epsilon:0.13....b_per:0.75.....experience:402300.00
# blue bananas 1 nothing 289 yellow bananas 10
#
# Episode:1342......Average Score:12.34......Epsilon:0.13....b_per:0.75.....experience:402600.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1343......Average Score:12.31......Epsilon:0.13....b_per:0.75.....experience:402900.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1344......Average Score:12.35......Epsilon:0.13....b_per:0.75.....experience:403200.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1345......Average Score:12.36......Epsilon:0.13....b_per:0.75.....experience:403500.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1346......Average Score:12.29......Epsilon:0.13....b_per:0.75.....experience:403800.00
# blue bananas 1 nothing 287 yellow bananas 12
#
# Episode:1347......Average Score:12.33......Epsilon:0.13....b_per:0.75.....experience:404100.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1348......Average Score:12.28......Epsilon:0.13....b_per:0.75.....experience:404400.00
# blue bananas 0 nothing 291 yellow bananas 9
#
# Episode:1349......Average Score:12.28......Epsilon:0.13....b_per:0.75.....experience:404700.00
# blue bananas 1 nothing 289 yellow bananas 10
#
# Episode:1350......Average Score:12.23......Epsilon:0.13....b_per:0.75.....experience:405000.00
# blue bananas 0 nothing 291 yellow bananas 9
#
# Episode:1351......Average Score:12.19......Epsilon:0.13....b_per:0.75.....experience:405300.00
# blue bananas 1 nothing 289 yellow bananas 10
#
# Episode:1352......Average Score:12.25......Epsilon:0.13....b_per:0.75.....experience:405600.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1353......Average Score:12.30......Epsilon:0.13....b_per:0.75.....experience:405900.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1354......Average Score:12.25......Epsilon:0.13....b_per:0.75.....experience:406200.00
# blue bananas 0 nothing 294 yellow bananas 6
#
# Episode:1355......Average Score:12.15......Epsilon:0.13....b_per:0.75.....experience:406500.00
# blue bananas 0 nothing 293 yellow bananas 7
#
# Episode:1356......Average Score:12.05......Epsilon:0.13....b_per:0.75.....experience:406800.00
# blue bananas 0 nothing 290 yellow bananas 10
#
# Episode:1357......Average Score:12.02......Epsilon:0.13....b_per:0.75.....experience:407100.00
# blue bananas 0 nothing 290 yellow bananas 10
#
# Episode:1358......Average Score:12.01......Epsilon:0.13....b_per:0.75.....experience:407400.00
# blue bananas 1 nothing 286 yellow bananas 13
#
# Episode:1359......Average Score:12.10......Epsilon:0.13....b_per:0.75.....experience:407700.00
# blue bananas 1 nothing 282 yellow bananas 17
#
# Episode:1360......Average Score:12.20......Epsilon:0.13....b_per:0.75.....experience:408000.00
# blue bananas 0 nothing 282 yellow bananas 18
#
# Episode:1361......Average Score:12.24......Epsilon:0.13....b_per:0.76.....experience:408300.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1362......Average Score:12.25......Epsilon:0.13....b_per:0.76.....experience:408600.00
# blue bananas 1 nothing 288 yellow bananas 11
#
# Episode:1363......Average Score:12.30......Epsilon:0.13....b_per:0.76.....experience:408900.00
# blue bananas 0 nothing 288 yellow bananas 12
#
# Episode:1364......Average Score:12.25......Epsilon:0.13....b_per:0.76.....experience:409200.00
# blue bananas 0 nothing 291 yellow bananas 9
#
# Episode:1365......Average Score:12.29......Epsilon:0.13....b_per:0.76.....experience:409500.00
# blue bananas 1 nothing 280 yellow bananas 19
#
# Episode:1366......Average Score:12.35......Epsilon:0.13....b_per:0.76.....experience:409800.00
# blue bananas 0 nothing 285 yellow bananas 14
# blue bananas 0 nothing 282 yellow bananas 18
#
# Episode:1389......Average Score:12.77......Epsilon:0.12....b_per:0.76.....experience:416700.00
# blue bananas 0 nothing 279 yellow bananas 21
#
# Episode:1390......Average Score:12.82......Epsilon:0.12....b_per:0.76.....experience:417000.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1391......Average Score:12.86......Epsilon:0.12....b_per:0.76.....experience:417300.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1392......Average Score:12.87......Epsilon:0.12....b_per:0.76.....experience:417600.00
# blue bananas 0 nothing 287 yellow bananas 13
#
# Episode:1393......Average Score:12.92......Epsilon:0.12....b_per:0.76.....experience:417900.00
# blue bananas 0 nothing 287 yellow bananas 13
#
# Episode:1394......Average Score:12.92......Epsilon:0.12....b_per:0.76.....experience:418200.00
# blue bananas 1 nothing 289 yellow bananas 10
#
# Episode:1395......Average Score:12.97......Epsilon:0.12....b_per:0.76.....experience:418500.00
# blue bananas 0 nothing 286 yellow bananas 14
#
# Episode:1396......Average Score:12.98......Epsilon:0.12....b_per:0.76.....experience:418800.00
# blue bananas 0 nothing 284 yellow bananas 16
#
# Episode:1397......Average Score:12.98......Epsilon:0.12....b_per:0.76.....experience:419100.00
# blue bananas 1 nothing 285 yellow bananas 14
#
# Episode:1398......Average Score:12.97......Epsilon:0.12....b_per:0.76.....experience:419400.00
# blue bananas 0 nothing 285 yellow bananas 15
#
# Episode:1399......Average Score:12.98......Epsilon:0.12....b_per:0.76.....experience:419700.00
# blue bananas 1 nothing 286 yellow bananas 13
#
# Episode:1400......Average Score:13.00......Epsilon:0.12....b_per:0.76.....experience:420000.00
# blue bananas 1 nothing 283 yellow bananas 16
#
# Congratulations, problem solved!!!
# saving parameters...
# saving scores...

# %%
file_in = open('all_scores3.pickle', 'rb')
a = pickle.load(file_in)
print(a[-10:])
# Out:
# [12.859999999999999, 12.869999999999999, 12.92, 12.92, 12.970000000000001, 12.98, 12.98, 12.970000000000001, 12.98, 13.0]

# %%
# TEST the MODEL

scores = deque(maxlen=100)
all_scores=[]

# CREATE Dueling DQN
DUELING_DQN = Network()

# LOAD Trained Parameters
DUELING_DQN.load_state_dict(torch.load('parameters3.pt'))

# PLAY 100 Episodes
for i in range(1, 101):
    env_info = env.reset(train_mode=True)[brain_name]  
    state = env_info.vector_observations[0]            
    score = 0         
    
    while True:
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action = DUELING_DQN(state_tensor).argmax(dim=1).item()  
        env_info = env.step(action)[brain_name]        
        next_state = env_info.vector_observations[0]   
        reward = env_info.rewards[0]                   
        done = env_info.local_done[0]                  
        score += reward                                
        state = next_state                             
        if done:
            print('episode:', i, '.....score:', score)
            scores.append(score)
            break
            
print('average score 100 episodes:', np.average(scores))
# Out:
# episode: 1 .....score: 14.0
# episode: 2 .....score: 14.0
# episode: 3 .....score: 15.0
# episode: 4 .....score: 14.0
# episode: 5 .....score: 0.0
# episode: 6 .....score: 13.0
